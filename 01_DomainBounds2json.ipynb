# %%
# create a JSON with bounding parameters for each modeling domain
# get ncols, nrows, ll corner coordinates, and cell size from domain ascii files.

# %%
BEAU = {
    "name": 'BEAU',
    "Bbox": {'latmax' : 71.509,'latmin' : 67.540,'lonmax': -135.889,'lonmin': -166.914,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'1000' 
}

BRIS = {
    "name": 'BRIS',
    "Bbox": {'latmax' : 64.724,'latmin' : 53.731,'lonmax': -150.936,'lonmin': -167.943,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'1000' 
}

CHUK = {
    "name": 'CHUK',
    "Bbox": {'latmax' : 69.082,'latmin' : 62.529,'lonmax': -153.280,'lonmin': -168.704,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'1000' 
}

JUNE = {
    "name": 'JUNE',
    "Bbox": {'latmax' : 58.677,'latmin' : 57.700,'lonmax': -133.741,'lonmin': -136.640,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:26708',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'250'
}


KLAW = {
    "name": 'KLAW',
    "Bbox": {'latmax' : 55.975,'latmin' : 55.015,'lonmax': -131.755,'lonmin': -134.450,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:26708',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'250' 
}

SITK = {
    "name": 'SITK',
    "Bbox": {'latmax' : 57.587,'latmin' : 56.590,'lonmax': -134.275,'lonmin': -137.085,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:26708',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'250'
}

TAKU = {
    "name": 'TAKU',
    "Bbox": {'latmax' : 59.60,'latmin' : 57.75,'lonmax': -130.70,'lonmin': -134.90,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:26708',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'250' 
}

YUKO = {
    "name": 'YUKO',
    "Bbox": {'latmax' : 68.20,'latmin' : 59.90,'lonmax': -130.4,'lonmin': -167.288,},
    "st": "1988-09-01", 
    "ed": "2019-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize":'1000' 
}



NPRB_domains = {
    "BEAU": BEAU,
    "BRIS": BRIS,
    "CHUK": CHUK,
    "JUNE": JUNE,
    "KLAW":KLAW,
    "SITK":SITK,
    "TAKU":TAKU,
    "YUKO":YUKO
}

# %%
NPRB_domains.keys()
# Out:
# dict_keys(['BEAU', 'BRIS', 'CHUK', 'JUNE', 'KLAW', 'SITK', 'TAKU', 'YUKO'])

# %%
import json
json = json.dumps(NPRB_domains)
f = open('/nfs/attic/dfh/2020_NPRB/notebooks/NPRB_domains.json',"w")
f.write(json)
f.close()

# %%
# #save baseline .par file
# import json

# json = json.dumps(CSO_domains)
# f = open('/nfs/attic/dfh/Aragon2/CSOdata/CSO_domains.json',"w")
# f.write(json)
# f.close()
